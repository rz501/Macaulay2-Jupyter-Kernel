# %% [markdown]
# # Test Jupyter Output

# %% [markdown]
# This is pretty great! Make Macaulay2 great again! with $\log(x^2)$

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook
# plt.ion()

# %%
fr = pd.DataFrame(np.random.randn(10,5),columns=list('ABCDE'))

# %%
fr.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ```C++
# // this is rendering of C++
# int main() {
#     return 0;
# }
# ```
#
# ```Python
# # this is rendering of Python
# def foo():
#     pass
# ```

# %% [markdown]
# this is a `codeword` and this is
#
# | Tables   |      Are      |  Cool |
# |----------|:-------------:|------:|
# | col 1 is |  left-aligned | $1600 |
# | col 2 is |    centered   |   $12 |
# | col 3 is | right-aligned |    $1 |
#
# ebasi
