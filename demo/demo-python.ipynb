# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
fr = pd.DataFrame(np.random.randn(5,10))

# %%
fr
# Out:
#           0         1         2         3         4         5         6  \
# 0  1.427945  1.044939 -0.973576  0.717685 -1.380942 -0.685428 -0.104489
# 1  0.810501  0.912101  1.239642 -1.072089 -0.703398 -0.191632  0.770212
# 2  0.654450 -0.493151 -0.391760 -0.143606  1.303789 -0.791334 -0.340412
# 3 -1.142738  0.016792  0.810184  1.159978 -0.549101 -0.216382  0.647020
# 4  0.315891  0.848905  0.456958 -1.283111 -0.204719 -0.030366  0.886837
#
#           7         8         9
# 0 -1.523830 -1.430949  0.234910
# 1 -0.621628 -0.497556  1.893422
# 2  1.356814  2.077760 -0.980916
# 3 -0.260174  0.127409  0.280644
# 4  1.327009  1.402552  0.031220

# %%
fr.plot(grid=True)
